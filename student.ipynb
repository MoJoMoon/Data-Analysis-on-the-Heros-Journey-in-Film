# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Morgan Jones
# * Student pace: Full Time
# * Scheduled project review date/time:
# * Instructor name: Abhineet
# * Blog post URL:

# %% [markdown]
# # Make a markdown cell by putting cell in escape mode and pressing m

# %% [markdown]
# # Importing Libraries

# %% [markdown]
# First let's import the necessary libraries for this project, we will need:
# Pandas
# Matplotlib
# Seaborn
# Json

# %%
import gzip
import csv
import json
import pandas as pd

df_budget = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
df_budget.head(25)
# Out:
#     id  release_date                                             movie  \
# 0    1  Dec 18, 2009                                            Avatar
# 1    2  May 20, 2011       Pirates of the Caribbean: On Stranger Tides
# 2    3   Jun 7, 2019                                      Dark Phoenix
# 3    4   May 1, 2015                           Avengers: Age of Ultron
# 4    5  Dec 15, 2017                 Star Wars Ep. VIII: The Last Jedi
# 5    6  Dec 18, 2015              Star Wars Ep. VII: The Force Awakens
# 6    7  Apr 27, 2018                            Avengers: Infinity War
# 7    8  May 24, 2007        Pirates of the Caribbean: At Worldâs End
# 8    9  Nov 17, 2017                                    Justice League
# 9   10   Nov 6, 2015                                           Spectre
# 10  11  Jul 20, 2012                             The Dark Knight Rises
# 11  12  May 25, 2018                           Solo: A Star Wars Story
# ...

# %%
from glob import glob

# %%
csv_files = glob('dsc-mod-1-project-v2-1-onl01-dtsc-ft-012120/zippedData/.csv.gz')
csv_files
# Out:
# []

# %%
df_budget.tail(25)
# Out:
#       id  release_date                            movie production_budget  \
# 5757  58   Dec 1, 2003                     Steel Spirit           $20,000
# 5758  59  Nov 25, 2011                       The Ridges           $17,300
# 5759  60   Jun 2, 2006                  The Puffy Chair           $15,000
# 5760  61   Apr 2, 2010                 Breaking Upwards           $15,000
# 5761  62  Dec 31, 2014             Stories of Our Lives           $15,000
# 5762  63  Apr 11, 1997                   Pink Flamingos           $12,000
# 5763  64  Apr 28, 2006         Grip: A Criminal's Story           $12,000
# 5764  65  Dec 31, 2007                      Tin Can Man           $12,000
# 5765  66   Mar 9, 2001                          Dayereh           $10,000
# 5766  67  Apr 28, 2006                            Clean           $10,000
# 5767  68   Jul 6, 2001                             Cure           $10,000
# 5768  69  May 28, 2004                   On the Downlow           $10,000
# ...

# %%
df_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
df_budget.describe()
# Out:
#                 id
# count  5782.000000
# mean     50.372363
# std      28.821076
# min       1.000000
# 25%      25.000000
# 50%      50.000000
# 75%      75.000000
# max     100.000000

# %%
df_budget.duplicated().values.any()
# Out:
# False

# %%
df_budget.isnull().values.any()
# Out:
# False

# %%
df_dates = pd.read_csv('zippedData/tmdb.movies.csv.gz')
df_dates.sort_values(by=['id'], ascending=True).head(25)
# Out:
#        Unnamed: 0            genre_ids   id original_language  \
# 117           117   [18, 10402, 10749]   27                en
# 23872       23872      [878, 9648, 12]   62                en
# 2510         2510         [28, 35, 80]   90                en
# 11109       11109   [80, 18, 9648, 53]   93                en
# 32             32    [28, 53, 878, 12]   95                en
# 2567         2567        [878, 28, 12]   97                en
# 14173       14173      [16, 10751, 14]  129                ja
# 20626       20626      [16, 10751, 14]  129                ja
# 14335       14335          [18, 10752]  143                en
# 11055       11055       [27, 9648, 80]  176                en
# 11047       11047             [80, 53]  189                en
# 24186       24186                 [18]  221                en
# 24000       24000          [35, 10749]  239                en
# 43             43          [35, 10749]  239                en
# ...

# %%
df_dates.tail(25)
# Out:
#        Unnamed: 0        genre_ids      id original_language  \
# 26492       26492               []  582641                en
# 26493       26493             [27]  571817                en
# 26494       26494             [18]  567020                es
# 26495       26495               []  556601                en
# 26496       26496             [99]  524548                en
# 26497       26497               []  514045                en
# 26498       26498               []  497839                en
# 26499       26499             [27]  589607                en
# 26500       26500               []  561932                en
# 26501       26501             [27]  558305                en
# 26502       26502             [16]  551756                en
# 26503       26503             [99]  543481                de
# 26504       26504     [27, 35, 27]  534282                en
# 26505       26505         [27, 53]  566092                en
# ...

# %%
df_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# Unnamed: 0           26517 non-null int64
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
df_dates.describe()
# Out:
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# min        0.00000      27.000000      0.600000      0.000000      1.000000
# 25%     6629.00000  157851.000000      0.600000      5.000000      2.000000
# 50%    13258.00000  309581.000000      1.374000      6.000000      5.000000
# 75%    19887.00000  419542.000000      3.694000      7.000000     28.000000
# max    26516.00000  608444.000000     80.773000     10.000000  22186.000000

# %%
df_dates.duplicated().values.any()
# Out:
# False

# %%
df_dates.isnull().values.any()
# Out:
# False

# %%
# After cleaning lets combine the IMDB df's with SQL using join, join on tconst,
# get the title from title basics, and combine df_ratings, df_principals, df_crew, df_time_gen

# %%
df_ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
df_ratings.head(25)
# Out:
#         tconst  averagerating  numvotes
# 0   tt10356526            8.3        31
# 1   tt10384606            8.9       559
# 2    tt1042974            6.4        20
# 3    tt1043726            4.2     50352
# 4    tt1060240            6.5        21
# 5    tt1069246            6.2       326
# 6    tt1094666            7.0      1613
# 7    tt1130982            6.4       571
# 8    tt1156528            7.2       265
# 9    tt1161457            4.2       148
# 10   tt1171222            5.1      8296
# 11   tt1174693            5.8      2381
# 12   tt1181840            7.0      5494
# 13   tt1193623            8.0         5
# 14   tt1199588            5.5        74
# 15   tt1204784            5.8         6
# 16   tt1210166            7.6    326657
# 17   tt1212419            6.5     87288
# 18   tt1220911            5.0       941
# 19   tt1229238            7.4    428142
# 20   tt1232829            7.2    477771
# 21   tt1235548            6.6      2725
# ...

# %%
df_ratings.tail(25)
# Out:
#           tconst  averagerating  numvotes
# 73831  tt9558612            3.7      4057
# 73832  tt9575726            7.7       161
# 73833  tt9576110            6.8        65
# 73834  tt9590776            9.2        37
# 73835  tt9591766            6.7         9
# 73836  tt9613538            4.3        26
# 73837  tt9617614            6.8        32
# 73838  tt9619016            7.0        27
# 73839  tt9633108            3.9        44
# 73840  tt9642950            6.0        22
# 73841  tt9643092            6.3        12
# 73842  tt9647642            2.0         5
# 73843  tt9657910            5.0         7
# 73844  tt9668598            5.5       317
# 73845  tt9690762            5.6        37
# 73846  tt9691896            6.3        21
# 73847  tt9708284            4.9        19
# 73848  tt9722952            7.0         6
# 73849  tt9768966            8.6        27
# 73850  tt9783738            7.4         7
# 73851  tt9805820            8.1        25
# ...

# %%
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
df_ratings.describe()
# Out:
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
df_ratings.duplicated().values.any()
# Out:
# False

# %%
df_ratings.isnull().values.any()
# Out:
# False

# %%
df_principals = pd.read_csv('zippedData/imdb.title.principals.csv.gz')
df_principals.head(25)
# Out:
#        tconst  ordering     nconst         category       job  \
# 0   tt0111414         1  nm0246005            actor       NaN
# 1   tt0111414         2  nm0398271         director       NaN
# 2   tt0111414         3  nm3739909         producer  producer
# 3   tt0323808        10  nm0059247           editor       NaN
# 4   tt0323808         1  nm3579312          actress       NaN
# 5   tt0323808         2  nm2694680            actor       NaN
# 6   tt0323808         3  nm0574615            actor       NaN
# 7   tt0323808         4  nm0502652          actress       NaN
# 8   tt0323808         5  nm0362736         director       NaN
# 9   tt0323808         6  nm0811056         producer  producer
# 10  tt0323808         7  nm0914939         producer  producer
# 11  tt0323808         8  nm0779346         composer       NaN
# 12  tt0323808         9  nm0676104  cinematographer       NaN
# 13  tt0417610        10  nm0284261         composer       NaN
# ...

# %%
df_principals.tail(25)
# Out:
#             tconst  ordering      nconst         category       job  \
# 1028161  tt9679036         1   nm9742452          actress       NaN
# 1028162  tt9679036         2  nm10435077            actor       NaN
# 1028163  tt9679036         3   nm7751067          actress       NaN
# 1028164  tt9679036         4  nm10435078          actress       NaN
# 1028165  tt9679036         5   nm9728620         director       NaN
# 1028166  tt9679036         6   nm8336361         composer       NaN
# 1028167  tt9681728         1   nm7681636            actor       NaN
# 1028168  tt9681728         2  nm10436664            actor       NaN
# 1028169  tt9681728         3   nm8254972            actor       NaN
# 1028170  tt9681728         4  nm10436662            actor       NaN
# 1028171  tt9681728         5  nm10436661         director       NaN
# 1028172  tt9681728         6   nm7442758         producer  producer
# 1028173  tt9681728         7   nm9645603  cinematographer       NaN
# ...

# %%
df_crew = pd.read_csv('zippedData/imdb.title.crew.csv.gz')
df_crew.head(25)
# Out:
#         tconst                      directors  \
# 0    tt0285252                      nm0899854
# 1    tt0438973                            NaN
# 2    tt0462036                      nm1940585
# 3    tt0835418                      nm0151540
# 4    tt0878654  nm0089502,nm2291498,nm2292011
# 5    tt0879859                      nm2416460
# 6    tt0996958                      nm2286991
# 7    tt0999913                      nm0527109
# 8   tt10003792                     nm10539228
# 9   tt10005130                     nm10540239
# 10  tt10005378                      nm9232888
# 11  tt10011102                      nm4853354
# 12   tt1002965                      nm0860520
# 13  tt10036406                     nm10553970
# 14  tt10039152                      nm6021959
# 15  tt10042456                      nm6051389
# 16  tt10055770                      nm8351963
# 17  tt10056334                     nm10563021
# 18  tt10059624                      nm0472248
# ...

# %%
df_crew.tail(25)
# Out:
#            tconst              directors  \
# 146119  tt8936646              nm1092087
# 146120  tt8947660             nm10097606
# 146121  tt8948466  nm10079230,nm10098149
# 146122  tt8948614    nm0827830,nm0839064
# 146123  tt8954732              nm0737517
# 146124  tt8959010              nm3912308
# 146125  tt8964244              nm5640537
# 146126  tt8965390             nm10105385
# 146127  tt8966354              nm0093946
# 146128  tt8971378              nm8355693
# 146129  tt8976710              nm1639277
# 146130  tt8978190              nm5176932
# 146131  tt8982244              nm7108143
# 146132  tt8991416              nm7731173
# 146133  tt8992390              nm0504267
# 146134  tt8992954              nm4927970
# 146135  tt8993410              nm1410292
# 146136  tt8996424              nm7477810
# 146137  tt8998302             nm10121510
# 146138  tt8999892             nm10122247
# 146139  tt8999974             nm10122357
# 146140  tt9001390              nm6711477
# ...

# %%
df_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
# tconst       146144 non-null object
# directors    140417 non-null object
# writers      110261 non-null object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
df_crew.describe()
# Out:
#            tconst  directors    writers
# count      146144     140417     110261
# unique     146144      98525      91920
# top     tt1757771  nm3266654  nm0000636
# freq            1         62         80

# %%
df_crew.duplicated().values.any()
# Out:
# False

# %%
df_crew.isnull().values.any()
# Out:
# True

# %%
df_crew.isnull().sum()
# Out:
# tconst           0
# directors     5727
# writers      35883
# dtype: int64

# %%
df_crew['writers'].nunique()
# Out:
# 91920

# %% [markdown]
#  There are thousands of data points missing from the directors and writers columns. Let's find out the percentage of missing data.

# %%
miss_writer = (df_crew['writers'].isnull().sum()) / len(df_crew) * 100
print( "The percentage of missing writer values is {}%.".format(miss_writer))
# Out:
# The percentage of missing writer values is 24.55318042478651%.

# %% [markdown]
# Almost 1/4th of our writer data is missing, this is problematic. We may want to drop this column.

# %%
miss_direct = (df_crew['directors'].isnull().sum()) / len(df_crew) * 100
print( "The percentage of missing director values is {}%.".format(miss_direct))
# Out:
# The percentage of missing director values is 3.9187376833807748%.

# %% [markdown]
# Only 4 percent of director data points are missing. We can drop these rows.

# %%
df_time_gen = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
df_time_gen.head(25)
# Out:
#        tconst                                      primary_title  \
# 0   tt0063540                                          Sunghursh
# 1   tt0066787                    One Day Before the Rainy Season
# 2   tt0069049                         The Other Side of the Wind
# 3   tt0069204                                    Sabse Bada Sukh
# 4   tt0100275                           The Wandering Soap Opera
# 5   tt0111414                                        A Thin Life
# 6   tt0112502                                            Bigfoot
# 7   tt0137204                                    Joe Finds Grace
# 8   tt0139613                                         O Silêncio
# 9   tt0144449                              Nema aviona za Zagreb
# 10  tt0146592                                        Pál Adrienn
# 11  tt0154039                               So Much for Justice!
# 12  tt0159369                 Cooper and Hemingway: The True Gen
# ...

# %%
df_time_gen.tail(25)
# Out:
#            tconst                                      primary_title  \
# 146119  tt9913594                                        Bacchanalia
# 146120  tt9913936                                           Paradise
# 146121  tt9914254                                      A Cherry Tale
# 146122  tt9914286                                  Sokagin Çocuklari
# 146123  tt9914368                                     Kuttram Seiyel
# 146124  tt9914522                             The Holden Family Plan
# 146125  tt9914642                                          Albatross
# 146126  tt9914644                       9/11: Escape from the Towers
# 146127  tt9914662                        Wien is 't Hof van Commerce
# 146128  tt9914828                                The War of Godzilla
# 146129  tt9914942                         La vida sense la Sara Amat
# 146130  tt9915436                                  Vida em Movimento
# 146131  tt9915790                                    Bobbyr Bondhura
# ...

# %%
df_time_gen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df_time_gen.describe()
# Out:
#           start_year  runtime_minutes
# count  146144.000000    114405.000000
# mean     2014.621798        86.187247
# std         2.733583       166.360590
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2015.000000        87.000000
# 75%      2017.000000        99.000000
# max      2115.000000     51420.000000

# %%
df_time_gen.duplicated().values.any()
# Out:
# False

# %%
df_time_gen.isnull().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
df_time_gen.isnull().sum().sum()
# Out:
# 37168

# %%
miss_minute = (df_time_gen['runtime_minutes'].isnull().sum() / len(df_time_gen)) * 100
print( "The percentage of missing runtime minutes values is {}%.".format(miss_minute))
# Out:
# The percentage of missing runtime minutes values is 21.71762097657105%.

# %%
percent = lambda a,b: a.isnull().sum() / len(b) * 100
percent(df_time_gen['runtime_minutes'],df_time_gen)
# Out:
# 21.71762097657105

# %%
percent(df_time_gen['genres'],df_time_gen)
# Out:
# 3.7004598204510617

# %%
miss_genre = (df_time_gen['genres'].isnull().sum() / len(df_time_gen)) * 100
print( "The percentage of missing genre values is {}%.".format(miss_genre))
# Out:
# The percentage of missing genre values is 3.7004598204510617%.

# %%
df_crew2 = pd.read_csv('zippedData/imdb.name.basics.csv.gz')
df_crew2.head(25)
# Out:
#        nconst           primary_name  birth_year  death_year  \
# 0   nm0061671      Mary Ellen Bauder         NaN         NaN
# 1   nm0061865           Joseph Bauer         NaN         NaN
# 2   nm0062070             Bruce Baum         NaN         NaN
# 3   nm0062195           Axel Baumann         NaN         NaN
# 4   nm0062798            Pete Baxter         NaN         NaN
# 5   nm0062879         Ruel S. Bayani         NaN         NaN
# 6   nm0063198                  Bayou         NaN         NaN
# 7   nm0063432          Stevie Be-Zet         NaN         NaN
# 8   nm0063618              Jeff Beal      1963.0         NaN
# 9   nm0063750        Lindsay Beamish         NaN         NaN
# 10  nm0064023          Bryan Beasley         NaN         NaN
# 11  nm0064350     Martine Beauchemin         NaN         NaN
# 12  nm0065847  Michael Frost Beckner      1963.0         NaN
# 13  nm0065919            Will Becton         NaN         NaN
# ...

# %%
df_crew2.tail(25)
# Out:
#            nconst           primary_name  birth_year  death_year  \
# 606623  nm9976769       Edyta Przytulska         NaN         NaN
# 606624  nm9977609  Amenkai Pilgrim-Owens         NaN         NaN
# 606625  nm9978371          Zach Campbell         NaN         NaN
# 606626  nm9979898           Ryosuke Yusa         NaN         NaN
# 606627  nm9980588      Elina Gakou Gomba         NaN         NaN
# 606628  nm9980896         Rama Narayanan         NaN         NaN
# 606629  nm9981679            Samir Eshra         NaN         NaN
# 606630  nm9981999         Kamlesh Israni         NaN         NaN
# 606631  nm9983730        Choi Yeong-Hwan         NaN         NaN
# 606632  nm9983906         Alejandro Odom         NaN         NaN
# 606633  nm9985838      Anthony Simonetti         NaN         NaN
# 606634  nm9985863             Gary Evans         NaN         NaN
# 606635  nm9986856       Geraldine Caster         NaN         NaN
# ...

# %%
df_crew2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
# nconst                606648 non-null object
# primary_name          606648 non-null object
# birth_year            82736 non-null float64
# death_year            6783 non-null float64
# primary_profession    555308 non-null object
# known_for_titles      576444 non-null object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB

# %%
df_crew2.describe()
# Out:
#          birth_year   death_year
# count  82736.000000  6783.000000
# mean    1967.043826  2000.523367
# std       22.122190    43.951530
# min        1.000000    17.000000
# 25%     1957.000000  2001.000000
# 50%     1971.000000  2013.000000
# 75%     1981.000000  2016.000000
# max     2014.000000  2019.000000

# %%
df_crew2.duplicated().values.any()
# Out:
# False

# %%
df_crew2.isnull().sum()
# Out:
# nconst                     0
# primary_name               0
# birth_year            523912
# death_year            599865
# primary_profession     51340
# known_for_titles       30204
# dtype: int64

# %% [markdown]
# The primary profession and known for titles may be the only columns we can in this dataset.

# %%
df_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
df_gross.head(25)
# Out:
#                                                 title   studio  \
# 0                                         Toy Story 3       BV
# 1                          Alice in Wonderland (2010)       BV
# 2         Harry Potter and the Deathly Hallows Part 1       WB
# 3                                           Inception       WB
# 4                                 Shrek Forever After     P/DW
# 5                          The Twilight Saga: Eclipse     Sum.
# 6                                          Iron Man 2     Par.
# 7                                             Tangled       BV
# 8                                       Despicable Me     Uni.
# 9                            How to Train Your Dragon     P/DW
# 10                         Clash of the Titans (2010)       WB
# 11  The Chronicles of Narnia: The Voyage of the Da...      Fox
# 12                                  The King's Speech    Wein.
# 13                                        Tron Legacy       BV
# ...

# %%
df_gross.tail(25)
# Out:
#                                                   title      studio  \
# 3362                                   Oolong Courtyard          CL
# 3363                                 Girls vs Gangsters       WGUSA
# 3364                              No Date, No Signature    Distrib.
# 3365                              The Apparition (2018)        MBox
# 3366                                        The Charmer          FM
# 3367                      Elliot: The Littlest Reindeer       Scre.
# 3368                                       The Workshop      Strand
# 3369                                       Loving Pablo        Uni.
# 3370                                  A Paris Education          KL
# 3371                          Tag Along: The Devil Fish          CL
# 3372                           Gabriel and the Mountain      Strand
# 3373                  Marlina the Murderer in Four Acts       Icar.
# 3374                                         The Escape         IFC
# ...

# %%
df_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df_gross.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
df_gross.duplicated().values.any()
# Out:
# False

# %%
df_gross.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
miss_studio = (df_gross['studio'].isnull().sum() / len(df_gross)) * 100
print( "The percentage of missing studio vales is {}%.".format(miss_studio))
# Out:
# The percentage of missing studio vales is 0.14762326542663123%.

# %%
miss_dom_gross = (df_gross['domestic_gross'].isnull().sum() / len(df_gross)) * 100
print( "The percentage of missing domestic gross values is {}%.".format(miss_dom_gross))
# Out:
# The percentage of missing domestic gross values is 0.8266902863891349%.

# %%
miss_for_gross = (df_gross['foreign_gross'].isnull().sum() / len(df_gross)) * 100
print( "The percentage of missing foreign gross values is {}%.".format(miss_for_gross))
# Out:
# The percentage of missing foreign gross values is 39.85828166519043%.
